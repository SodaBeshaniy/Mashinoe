# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.23.5)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.11.3)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.2.0)

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('heart.csv')
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0      172              N      0.0       Up             0
# 1      156              N      1.0     Flat             1
# 2       98              N      0.0       Up             0
# 3      108              Y      1.5     Flat             1
# 4      122              N      0.0       Up             0
# ..     ...            ...      ...      ...           ...
# 913    132              N      1.2     Flat             1
# 914    141              N      3.4     Flat             1
# 915    115              Y      1.2     Flat             1
# 916    174              N      0.0     Flat             1
# 917    173              N      0.0       Up             0
#
# [918 rows x 12 columns]

# %%
#Удаление
df_cleaned = df.dropna()

df_cleaned
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0      172              N      0.0       Up             0
# 1      156              N      1.0     Flat             1
# 2       98              N      0.0       Up             0
# 3      108              Y      1.5     Flat             1
# 4      122              N      0.0       Up             0
# ..     ...            ...      ...      ...           ...
# 913    132              N      1.2     Flat             1
# 914    141              N      3.4     Flat             1
# 915    115              Y      1.2     Flat             1
# 916    174              N      0.0     Flat             1
# 917    173              N      0.0       Up             0
#
# [918 rows x 12 columns]

# %%
import pandas as pd
import numpy as np
def create_holes(dataframe, column_name, hole_percentage = 10):

    if hole_percentage < 0 or hole_percentage > 100:
        raise ValueError("Процент дырявости должен быть в диапазоне от 0 до 100.")

    dataframe_with_holes = dataframe.copy()
    num_holes = int(len(dataframe) * (hole_percentage / 100))
    hole_indices = np.random.choice(len(dataframe), num_holes, replace=False)
    dataframe_with_holes.loc[hole_indices, column_name] = np.nan

    return dataframe_with_holes


df = create_holes(df, 'Age')
df
# Out:
#       Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0    40.0   M           ATA        140          289          0     Normal
# 1    49.0   F           NAP        160          180          0     Normal
# 2    37.0   M           ATA        130          283          0         ST
# 3    48.0   F           ASY        138          214          0     Normal
# 4    54.0   M           NAP        150          195          0     Normal
# ..    ...  ..           ...        ...          ...        ...        ...
# 913  45.0   M            TA        110          264          0     Normal
# 914  68.0   M           ASY        144          193          1     Normal
# 915  57.0   M           ASY        130          131          0     Normal
# 916  57.0   F           ATA        130          236          0        LVH
# 917  38.0   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0      172              N      0.0       Up             0
# 1      156              N      1.0     Flat             1
# 2       98              N      0.0       Up             0
# 3      108              Y      1.5     Flat             1
# 4      122              N      0.0       Up             0
# ..     ...            ...      ...      ...           ...
# 913    132              N      1.2     Flat             1
# 914    141              N      3.4     Flat             1
# 915    115              Y      1.2     Flat             1
# 916    174              N      0.0     Flat             1
# 917    173              N      0.0       Up             0
#
# [918 rows x 12 columns]

# %%
df_filled_mean = df.fillna(df['Age'].mean())

df_filled_mean
# Out:
#       Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0    40.0   M           ATA        140          289          0     Normal
# 1    49.0   F           NAP        160          180          0     Normal
# 2    37.0   M           ATA        130          283          0         ST
# 3    48.0   F           ASY        138          214          0     Normal
# 4    54.0   M           NAP        150          195          0     Normal
# ..    ...  ..           ...        ...          ...        ...        ...
# 913  45.0   M            TA        110          264          0     Normal
# 914  68.0   M           ASY        144          193          1     Normal
# 915  57.0   M           ASY        130          131          0     Normal
# 916  57.0   F           ATA        130          236          0        LVH
# 917  38.0   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0      172              N      0.0       Up             0
# 1      156              N      1.0     Flat             1
# 2       98              N      0.0       Up             0
# 3      108              Y      1.5     Flat             1
# 4      122              N      0.0       Up             0
# ..     ...            ...      ...      ...           ...
# 913    132              N      1.2     Flat             1
# 914    141              N      3.4     Flat             1
# 915    115              Y      1.2     Flat             1
# 916    174              N      0.0     Flat             1
# 917    173              N      0.0       Up             0
#
# [918 rows x 12 columns]

# %%
#Заполнение при помощи среднего
df_filled_median = df.fillna(df["Age"].median())

df_filled_median
# Out:
#       Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0    40.0   M           ATA        140          289          0     Normal
# 1    49.0   F           NAP        160          180          0     Normal
# 2    37.0   M           ATA        130          283          0         ST
# 3    48.0   F           ASY        138          214          0     Normal
# 4    54.0   M           NAP        150          195          0     Normal
# ..    ...  ..           ...        ...          ...        ...        ...
# 913  45.0   M            TA        110          264          0     Normal
# 914  68.0   M           ASY        144          193          1     Normal
# 915  57.0   M           ASY        130          131          0     Normal
# 916  57.0   F           ATA        130          236          0        LVH
# 917  38.0   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0      172              N      0.0       Up             0
# 1      156              N      1.0     Flat             1
# 2       98              N      0.0       Up             0
# 3      108              Y      1.5     Flat             1
# 4      122              N      0.0       Up             0
# ..     ...            ...      ...      ...           ...
# 913    132              N      1.2     Flat             1
# 914    141              N      3.4     Flat             1
# 915    115              Y      1.2     Flat             1
# 916    174              N      0.0     Flat             1
# 917    173              N      0.0       Up             0
#
# [918 rows x 12 columns]

# %%
#Заполнение при помощи моды

df_filled_mode = df.fillna(df["ChestPainType"].mode()[0])
"""
Мода возвращает объект Series, так как
значений моды может быть несколько
"""
df_filled_mode
# Out:
#       Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0    40.0   M           ATA        140          289          0     Normal
# 1    49.0   F           NAP        160          180          0     Normal
# 2    37.0   M           ATA        130          283          0         ST
# 3    48.0   F           ASY        138          214          0     Normal
# 4    54.0   M           NAP        150          195          0     Normal
# ..    ...  ..           ...        ...          ...        ...        ...
# 913  45.0   M            TA        110          264          0     Normal
# 914  68.0   M           ASY        144          193          1     Normal
# 915  57.0   M           ASY        130          131          0     Normal
# 916  57.0   F           ATA        130          236          0        LVH
# 917  38.0   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0      172              N      0.0       Up             0
# 1      156              N      1.0     Flat             1
# 2       98              N      0.0       Up             0
# 3      108              Y      1.5     Flat             1
# 4      122              N      0.0       Up             0
# ..     ...            ...      ...      ...           ...
# 913    132              N      1.2     Flat             1
# 914    141              N      3.4     Flat             1
# 915    115              Y      1.2     Flat             1
# 916    174              N      0.0     Flat             1
# 917    173              N      0.0       Up             0
#
# [918 rows x 12 columns]

# %%
#Заполнение при помощи моды
df_filled_mode = df.fillna(df["Age"].mode()[0])
"""
Мода возвращает объект Series, так как
значений моды может быть несколько
"""
df_filled_mode
# Out:
#       Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0    40.0   M           ATA        140          289          0     Normal
# 1    49.0   F           NAP        160          180          0     Normal
# 2    37.0   M           ATA        130          283          0         ST
# 3    48.0   F           ASY        138          214          0     Normal
# 4    54.0   M           NAP        150          195          0     Normal
# ..    ...  ..           ...        ...          ...        ...        ...
# 913  45.0   M            TA        110          264          0     Normal
# 914  68.0   M           ASY        144          193          1     Normal
# 915  57.0   M           ASY        130          131          0     Normal
# 916  57.0   F           ATA        130          236          0        LVH
# 917  38.0   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0      172              N      0.0       Up             0
# 1      156              N      1.0     Flat             1
# 2       98              N      0.0       Up             0
# 3      108              Y      1.5     Flat             1
# 4      122              N      0.0       Up             0
# ..     ...            ...      ...      ...           ...
# 913    132              N      1.2     Flat             1
# 914    141              N      3.4     Flat             1
# 915    115              Y      1.2     Flat             1
# 916    174              N      0.0     Flat             1
# 917    173              N      0.0       Up             0
#
# [918 rows x 12 columns]

# %%
#Заполнение при помощи моды
df_filled_mode = df.fillna(df["ChestPainType"].mode()[0])

df_filled_mode
# Out:
#       Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0    40.0   M           ATA        140          289          0     Normal
# 1    49.0   F           NAP        160          180          0     Normal
# 2    37.0   M           ATA        130          283          0         ST
# 3    48.0   F           ASY        138          214          0     Normal
# 4    54.0   M           NAP        150          195          0     Normal
# ..    ...  ..           ...        ...          ...        ...        ...
# 913  45.0   M            TA        110          264          0     Normal
# 914  68.0   M           ASY        144          193          1     Normal
# 915  57.0   M           ASY        130          131          0     Normal
# 916  57.0   F           ATA        130          236          0        LVH
# 917  38.0   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0      172              N      0.0       Up             0
# 1      156              N      1.0     Flat             1
# 2       98              N      0.0       Up             0
# 3      108              Y      1.5     Flat             1
# 4      122              N      0.0       Up             0
# ..     ...            ...      ...      ...           ...
# 913    132              N      1.2     Flat             1
# 914    141              N      3.4     Flat             1
# 915    115              Y      1.2     Flat             1
# 916    174              N      0.0     Flat             1
# 917    173              N      0.0       Up             0
#
# [918 rows x 12 columns]

# %%
df_interpolated = df["Age"].interpolate(method ='linear')

df_interpolated.describe()
# Out:
# count    918.000000
# mean      53.818083
# std        9.121546
# min       28.000000
# 25%       48.000000
# 50%       54.000000
# 75%       60.000000
# max       77.000000
# Name: Age, dtype: float64

# %% [markdown]
# **Объясните** Все методы изменилм стандартное отклонение. Заполнение модой уменьшило число свыше 75 квантиля, медиана его увеличила
#
# ***Поиск выбросов и аномалий***
# Те, кто выполняет задания со * делают поиск выбросов с помощью написанного ранее класса
#
# Найти выбросы по числовой переменной (использовать метод основанный на среднем и на межквартильном размахе). Объясните результат
#
# Вывести статистику с выбросами и без. Сравните и объясните результат

# %%
#затем измененную
#Методом среднего
mean_data = df["Age"].mean()
maximum = mean_data * 2
# res = []
# for item in df["Age"]:
#   if abs(item - mean_data) < maximum:
#     res.append(item)

df_mean = df[abs((df["Age"] - mean_data) < maximum)]
df_mean["Age"].describe()
# Out:
# count    827.000000
# mean      53.782346
# std        9.365256
# min       28.000000
# 25%       48.000000
# 50%       54.000000
# 75%       60.000000
# max       77.000000
# Name: Age, dtype: float64

# %%
#При помощи межквартильного размаха
Q1 =  df["Age"].quantile(0.25)
Q3 = df["Age"].quantile(0.75)
IQR = Q3 - Q1
df_IQR = df[(df["Age"] > (Q1-1.5*IQR )) & (df["Age"] < (Q3+1.5*IQR))]
df_IQR["Age"].describe()
# Out:
# count    823.000000
# mean      53.902795
# std        9.226550
# min       31.000000
# 25%       48.000000
# 50%       55.000000
# 75%       60.000000
# max       77.000000
# Name: Age, dtype: float64

# %% [markdown]
# Объяснения Отсечение по межквартильному размаху оставляет меньше значений и сильнее срезает максимум, чем через среднее значение.
#
# **Дубликаты**
# Проверьте датафрейм на дубликаты и удалите их, если дублей нет - создайте.

# %%
#Проверка на дубли
df = pd.read_csv('heart.csv')
dupls = df.duplicated()

count = 0
for i in dupls:
  if (i): count +=1

count
# Out:
# 0

# %%
df_with_dupls = pd.concat((df, df.loc[0:100]))
dupls = df_with_dupls.duplicated()
count = 0
for i in dupls:
  if (i): count +=1

count
# Out:
# 101

# %%
#Удаление дублей
df_no_duplicates = df_with_dupls.drop_duplicates()
dupls = df_no_duplicates.duplicated()

count = 0
for i in dupls:
  if (i): count +=1
count
# Out:
# 0

# %% [markdown]
# **Преобразование признаков**
# Масштабируйте числовые признаки через MinMaxScaler, StandardScaler

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# Creating instances

num_features = df.select_dtypes(include=['int']).columns
scaler_minmax = MinMaxScaler()
min_max_scaler = df.copy()
min_max_scaler[num_features] = scaler_minmax.fit_transform(df[num_features])
min_max_scaler["Cholesterol"].unique()
# Out:
# array([0.47927032, 0.29850746, 0.46932007, 0.35489221, 0.32338308,
#        0.56218905, 0.39303483, 0.34494196, 0.34328358, 0.47097844,
#        0.34991708, 0.27197347, 0.33830846, 0.3880597 , 0.45273632,
#        0.32504146, 0.33333333, 0.41127695, 0.44278607, 0.36981758,
#        0.30514096, 0.47761194, 0.35655058, 0.34660033, 0.43117745,
#        0.7761194 , 0.31177446, 0.85903814, 0.27694859, 0.37147595,
#        0.28524046, 0.30845771, 0.4212272 , 0.50746269, 0.4145937 ,
#        0.29353234, 0.37645108, 0.3814262 , 0.48756219, 0.43781095,
#        0.42951907, 0.29021559, 0.52736318, 0.35820896, 0.56384743,
#        0.38640133, 0.33996683, 0.40630182, 0.32172471, 0.44776119,
#        0.35323383, 0.6053068 , 0.56716418, 0.41956882, 0.45936982,
#        0.33499171, 0.49253731, 0.37313433, 0.4079602 , 0.68325041,
#        0.43946932, 0.30182421, 0.3615257 , 0.44444444, 0.27031509,
#        0.87728027, 0.16583748, 0.34162521, 0.3946932 , 0.2305141 ,
#        0.43615257, 0.48258706, 0.37976783, 0.50912106, 0.34825871,
#        0.54560531, 0.24378109, 0.14096186, 0.44610282, 0.45605307,
#        0.29684909, 0.65008292, 0.77280265, 0.21393035, 0.39966833,
#        0.42288557, 0.45771144, 0.46766169, 0.56053068, 0.26533997,
#        0.25870647, 0.45107794, 0.39800995, 0.65174129, 0.26699834,
#        0.37810945, 0.48424544, 0.64344942, 0.27529022, 0.40961857,
#        0.54892206, 0.5655058 , 0.40298507, 0.46268657, 0.32835821,
#        0.41293532, 0.27860697, 1.        , 0.26368159, 0.31509121,
#        0.30679934, 0.48092869, 0.35157546, 0.38308458, 0.3681592 ,
#        0.38971808, 0.53067993, 0.31011609, 0.44112769, 0.47595357,
#        0.66998342, 0.51741294, 0.41625207, 0.54394693, 0.47263682,
#        0.46434494, 0.31840796, 0.32006633, 0.51077944, 0.36318408,
#        0.42620232, 0.21890547, 0.3747927 , 0.35986733, 0.50248756,
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140     0.825070          0     Normal
# 1     49   F           NAP        160    -0.171961          0     Normal
# 2     37   M           ATA        130     0.770188          0         ST
# 3     48   F           ASY        138     0.139040          0     Normal
# 4     54   M           NAP        150    -0.034755          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110     0.596393          0     Normal
# 914   68   M           ASY        144    -0.053049          1     Normal
# 915   57   M           ASY        130    -0.620168          0     Normal
# 916   57   F           ATA        130     0.340275          0        LVH
# 917   38   M           NAP        138    -0.217696          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0      172              N      0.0       Up             0
# 1      156              N      1.0     Flat             1
# 2       98              N      0.0       Up             0
# 3      108              Y      1.5     Flat             1
# 4      122              N      0.0       Up             0
# ..     ...            ...      ...      ...           ...
# 913    132              N      1.2     Flat             1
# 914    141              N      3.4     Flat             1
# 915    115              Y      1.2     Flat             1
# 916    174              N      0.0     Flat             1
# 917    173              N      0.0       Up             0
#
# [918 rows x 12 columns]

# %% [markdown]
# Масштабируйте категориальные признаки через OneHotEncoder

# %%
from sklearn.preprocessing import OneHotEncoder

# Create an instance of OneHotEncoder
encoder = OneHotEncoder()
df["RestingECG"] = df["RestingECG"].astype("category")
df["ChestPainType"] = df["ChestPainType"].astype("category")
category_col = df.select_dtypes(include=['category']).columns
encoder = OneHotEncoder()
df_cat_encoded = pd.get_dummies(df, columns=category_col, drop_first=True)
encoded_features = encoder.fit_transform(df[category_col])
encoded_columns = encoder.get_feature_names_out(category_col)
encoded_columns
# Out:
# array(['ChestPainType_ASY', 'ChestPainType_ATA', 'ChestPainType_NAP',
#        'ChestPainType_TA', 'RestingECG_LVH', 'RestingECG_Normal',
#        'RestingECG_ST'], dtype=object)

# %%
df_cat_encoded
# Out:
#      Age Sex  RestingBP  Cholesterol  FastingBS  MaxHR ExerciseAngina  \
# 0     40   M        140          289          0    172              N
# 1     49   F        160          180          0    156              N
# 2     37   M        130          283          0     98              N
# 3     48   F        138          214          0    108              Y
# 4     54   M        150          195          0    122              N
# ..   ...  ..        ...          ...        ...    ...            ...
# 913   45   M        110          264          0    132              N
# 914   68   M        144          193          1    141              N
# 915   57   M        130          131          0    115              Y
# 916   57   F        130          236          0    174              N
# 917   38   M        138          175          0    173              N
#
#      Oldpeak ST_Slope  HeartDisease  ChestPainType_ATA  ChestPainType_NAP  \
# 0        0.0       Up             0                  1                  0
# 1        1.0     Flat             1                  0                  1
# 2        0.0       Up             0                  1                  0
# 3        1.5     Flat             1                  0                  0
# 4        0.0       Up             0                  0                  1
# ..       ...      ...           ...                ...                ...
# 913      1.2     Flat             1                  0                  0
# 914      3.4     Flat             1                  0                  0
# 915      1.2     Flat             1                  0                  0
# 916      0.0     Flat             1                  1                  0
# 917      0.0       Up             0                  0                  1
#
#      ChestPainType_TA  RestingECG_Normal  RestingECG_ST
# 0                   0                  1              0
# 1                   0                  1              0
# 2                   0                  0              1
# 3                   0                  1              0
# 4                   0                  1              0
# ..                ...                ...            ...
# 913                 1                  1              0
# 914                 0                  1              0
# 915                 0                  1              0
# 916                 0                  0              0
# 917                 0                  1              0
#
# [918 rows x 15 columns]
