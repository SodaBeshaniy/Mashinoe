# %%
# !pip install pandas
# !pip install seaborn

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
#  **Введение в описательную статистику**
#
# Выберите категориальную целевую переменную (Y)
#
# Выберите переменную для анализа относительно категории (X)
#
# Выведитие обобщенную статистическую информацию переменной (X)
#
# Вычислите среднее, медиану, моду, минимум, максимум, стандартное отклонение относительно целевой пременной из файла Classification datasets в соответствии с вашим вариантом
#
# Сделайте вывод относительно полученных результатов
#
# p.s если у вас нет категориальных признаков - преобразуйте любой числовой в категориальный (https://pandas.pydata.org/docs/reference/api/pandas.cut.html). Важно не использовать преобразованный Y вместе с этим же X (то есть, если вы преобразовали возраст в категорию, то вы не моежет использовать возраст в качестве X и возраст категорию в качестве Y)
#
# 1.   Новый пункт
#
# 1.   Новый пункт
# 2.   Новый пункт
#
#
# 2.   Новый пункт

# %%
df = pd.read_csv("world-data-2023.csv")
df
# Out:
#          Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 0    Afghanistan               60           AF                58.10%
# 1        Albania              105           AL                43.10%
# 2        Algeria               18           DZ                17.40%
# 3        Andorra              164           AD                40.00%
# 4         Angola               26           AO                47.50%
# ..           ...              ...          ...                   ...
# 190    Venezuela               32           VE                24.50%
# 191      Vietnam              314           VN                39.30%
# 192        Yemen               56           YE                44.60%
# 193       Zambia               25           ZM                32.10%
# 194     Zimbabwe               38           ZW                41.90%
#
#     Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# 0          652,230           323,000       32.49          93.0
# ...

# %%
g =  df.groupby(["Country"])
describe =g["Birth Rate"].describe()
describe
# Out:
#              count   mean  std    min    25%    50%    75%    max
# Country
# Afghanistan    1.0  32.49  NaN  32.49  32.49  32.49  32.49  32.49
# Albania        1.0  11.78  NaN  11.78  11.78  11.78  11.78  11.78
# Algeria        1.0  24.28  NaN  24.28  24.28  24.28  24.28  24.28
# Andorra        1.0   7.20  NaN   7.20   7.20   7.20   7.20   7.20
# Angola         1.0  40.73  NaN  40.73  40.73  40.73  40.73  40.73
# ...            ...    ...  ...    ...    ...    ...    ...    ...
# Venezuela      1.0  17.88  NaN  17.88  17.88  17.88  17.88  17.88
# Vietnam        1.0  16.75  NaN  16.75  16.75  16.75  16.75  16.75
# Yemen          1.0  30.45  NaN  30.45  30.45  30.45  30.45  30.45
# Zambia         1.0  36.19  NaN  36.19  36.19  36.19  36.19  36.19
# Zimbabwe       1.0  30.68  NaN  30.68  30.68  30.68  30.68  30.68
#
# [195 rows x 8 columns]

# %%
mean = g["Birth Rate"].mean()# (среднее) ваш код здесь
mean
# Out:
# Country
# Afghanistan    32.49
# Albania        11.78
# Algeria        24.28
# Andorra         7.20
# Angola         40.73
#                ...
# Venezuela      17.88
# Vietnam        16.75
# Yemen          30.45
# Zambia         36.19
# Zimbabwe       30.68
# Name: Birth Rate, Length: 195, dtype: float64

# %%
median = g["Birth Rate"].median()# (медиана) ваш код здесь
median
# Out:
# Country
# Afghanistan    32.49
# Albania        11.78
# Algeria        24.28
# Andorra         7.20
# Angola         40.73
#                ...
# Venezuela      17.88
# Vietnam        16.75
# Yemen          30.45
# Zambia         36.19
# Zimbabwe       30.68
# Name: Birth Rate, Length: 195, dtype: float64

# %%
mode = df["Birth Rate"].mode()# (мода) ваш код здесь mode
mode
# Out:
# 0    10.0
# 1    12.0
# Name: Birth Rate, dtype: float64

# %%
min = g["Birth Rate"].min()# (минимум) ваш код здесь
min
# Out:
# Country
# Afghanistan    32.49
# Albania        11.78
# Algeria        24.28
# Andorra         7.20
# Angola         40.73
#                ...
# Venezuela      17.88
# Vietnam        16.75
# Yemen          30.45
# Zambia         36.19
# Zimbabwe       30.68
# Name: Birth Rate, Length: 195, dtype: float64

# %%
max = g["Birth Rate"].max()# (максимум) ваш код здесь
max
# Out:
# Country
# Afghanistan    32.49
# Albania        11.78
# Algeria        24.28
# Andorra         7.20
# Angola         40.73
#                ...
# Venezuela      17.88
# Vietnam        16.75
# Yemen          30.45
# Zambia         36.19
# Zimbabwe       30.68
# Name: Birth Rate, Length: 195, dtype: float64

# %%
std = g["Birth Rate"].std()# (стандартное отклонение)
std
# Out:
# Country
# Afghanistan   NaN
# Albania       NaN
# Algeria       NaN
# Andorra       NaN
# Angola        NaN
#                ..
# Venezuela     NaN
# Vietnam       NaN
# Yemen         NaN
# Zambia        NaN
# Zimbabwe      NaN
# Name: Birth Rate, Length: 195, dtype: float64

# %%
q1 = g["Birth Rate"].quantile(0.25)# (25% квантиль)
q1
# Out:
# Country
# Afghanistan    32.49
# Albania        11.78
# Algeria        24.28
# Andorra         7.20
# Angola         40.73
#                ...
# Venezuela      17.88
# Vietnam        16.75
# Yemen          30.45
# Zambia         36.19
# Zimbabwe       30.68
# Name: Birth Rate, Length: 195, dtype: float64

# %%
q2 = g["Birth Rate"].quantile(0.5) # (50% квантиль)
q2
# Out:
# Country
# Afghanistan    32.49
# Albania        11.78
# Algeria        24.28
# Andorra         7.20
# Angola         40.73
#                ...
# Venezuela      17.88
# Vietnam        16.75
# Yemen          30.45
# Zambia         36.19
# Zimbabwe       30.68
# Name: Birth Rate, Length: 195, dtype: float64

# %%
q3 = g["Birth Rate"].quantile(0.75)# (75% квантиль)
q3
# Out:
# Country
# Afghanistan    32.49
# Albania        11.78
# Algeria        24.28
# Andorra         7.20
# Angola         40.73
#                ...
# Venezuela      17.88
# Vietnam        16.75
# Yemen          30.45
# Zambia         36.19
# Zimbabwe       30.68
# Name: Birth Rate, Length: 195, dtype: float64

# %%
iqr = q3 - q1# (интерквартильный размах)
iqr
# Out:
# Country
# Afghanistan    0.0
# Albania        0.0
# Algeria        0.0
# Andorra        0.0
# Angola         0.0
#               ...
# Venezuela      0.0
# Vietnam        0.0
# Yemen          0.0
# Zambia         0.0
# Zimbabwe       0.0
# Name: Birth Rate, Length: 195, dtype: float64

# %% [markdown]
# Какие выводы можно сделать исходя из полученных статистических данных?
#
# **Ответ здесь**
#
# Example: видим, что среднее и отклонение различается между группами, следовательно...
# Сделать подобные выводы относительно других статистических характеристик
#
# **Основы визуализации**
#
# Постройте гистограмму переменной (X) относительно категориального признака (Y) из своего датасета.

# %%
plt.figure(figsize=(40, 30))
sns.countplot(x='Birth Rate', hue='Country', data=df);
df.loc[df['Birth Rate'] == 41]
# Out:
# Empty DataFrame
# Columns: [Country, Density
# (P/Km2), Abbreviation, Agricultural Land( %), Land Area(Km2), Armed Forces size, Birth Rate, Calling Code, Capital/Major City, Co2-Emissions, CPI, CPI Change (%), Currency-Code, Fertility Rate, Forested Area (%), Gasoline Price, GDP, Gross primary education enrollment (%), Gross tertiary education enrollment (%), Infant mortality, Largest city, Life expectancy, Maternal mortality ratio, Minimum wage, Official language, Out of pocket health expenditure, Physicians per thousand, Population, Population: Labor force participation (%), Tax revenue (%), Total tax rate, Unemployment rate, Urban_population, Latitude, Longitude]
# Index: []
#
# [0 rows x 35 columns]

# %%
plt.figure(figsize=(4, 3))
plt.boxplot(df['Birth Rate'])

plt.show()

# %%
sns.boxplot(y="Country", x="Birth Rate", data=df)
# Out:
# <Axes: xlabel='Birth Rate', ylabel='Country'>

# %%
plt.figure(figsize=(4, 3))
plt.scatter(x=df['Longitude'], y=df['Latitude'], color='red')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()

# %%
num = df[['Latitude','Longitude']]
corr_matrix = num.corr()


plt.figure(figsize=(4, 4))
sns.heatmap(corr_matrix, annot=True)
# Out:
# <Axes: >
